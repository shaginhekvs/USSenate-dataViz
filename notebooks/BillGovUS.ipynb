# %%
try:
    from fake_useragent import UserAgent
except:
    # !pip install fake-useragent
import requests

# %%
ua = UserAgent()
#print(ua.chrome)
header = {'User-Agent':str(ua.chrome)}
print(header)
subject = "agriculture_and_food"
subject_id = 5816
facet = "true"
congress_num = 106
page_num = 1
url = "https://www.govtrack.us/congress/bills/subjects/{}/{}\\
    # ?congress={}&terms={}&sort=-introduced_date&page={}\\
    &faceting={}&allow_redirect=true&do_search=1".format(subject,subject_id,congress_num,subject_id,page_num,facet)
url = 'https://www.govtrack.us/congress/bills/subjects/agriculture_and_food/5816?congress=106&terms=5896&sort=-introduced_date&page=1&faceting=false&allow_redirect=true&do_search=1'
htmlContent = requests.get(url, headers=header)
# Out:
# {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_2) AppleWebKit/537.17 (KHTML, like Gecko) Chrome/24.0.1309.0 Safari/537.17'}

# %%
htmlContent.status_code
# Out:
# 200

# %%
result = htmlContent.json()

# %%
result
# Out:
# {'num_pages': 66,
#  'options': [['similar_to', 'text', None, False, False],
#   ['usc_cite', 'text', None, False, False],
#   ['text', 'text', None, False, True],
#   ['congress',
#    'select',
#    [['__ALL__', 'All', -1, None],
#     [106, '106th Congress: 1999-2000', 1308, None]],
#    True,
#    True],
#   ['sponsor', 'select', [['__ALL__', 'All', -1, None]], True, True],
#   ['current_status',
#    'checkbox',
#    [['__ALL__', 'All', -1, None],
#     [1,
#      'Introduced',
#      955,
#      'Introduced is the first step in the legislative process.'],
#     [3,
#      'Ordered Reported',
#      81,
#      'Ordered reported by a committee to the originating chamber.'],
#     [4,
#      'Passed House (Senate next)',
#      77,
#      'Passed the House, waiting for a Senate vote next.'],
#     [5,
#      'Passed Senate (House next)',
#      37,
#      'Passed the Senate, waiting for a House vote next.'],
#     [6,
#      'Agreed To (Simple Resolution)',
#      47,
# ...
